# %% [markdown]
# <a href="https://colab.research.google.com/github/Impossiblepretext/Experiment_No.8/blob/main/Experiment_No_8_NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment No.8
#
# Title: Tools for EDA- NumPy
#
# Name: Vibhas Shukla
#
# PRN: 25070123164
#
# Batch: F.Y Entc A1

# %%
import numpy as np
a=np.array([10,20,30,40])
b=np.array([[1,2,3],[4,5,6]])
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
a.shape
# Out:
# (4,)

# %%
b.shape
# Out:
# (2, 3)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.dtype
# Out:
# dtype('int64')

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((2))
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
np.arange(10,25,5)
# Out:
# array([10, 15, 20])

# %%
np.linspace(0,2,9)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
a+5
# Out:
# array([15, 25, 35, 45])

# %%
a*2
# Out:
# array([20, 40, 60, 80])

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.sum(a)
# Out:
# np.int64(100)
